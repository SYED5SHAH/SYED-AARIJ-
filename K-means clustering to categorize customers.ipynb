# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
import pandas as pd

train_df = pd.read_csv(r'C:\Users\DELL E7450\Desktop\Mall_Customers.csv')


# Step 3: Data Preprocessing
# Checking for missing values
print(train_df.isnull().sum())
data = train_df.drop(['CustomerID'], axis=1)

# Convert 'Gender' column to numerical values using Label Encoding
data['Gender'] = data['Gender'].map({'Male': 0, 'Female': 1})

# Now check if there are any more non-numeric columns
print(data.dtypes)

# Scaling the data (after converting categorical values)
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64
# Gender                    int64
# Age                       int64
# Annual Income (k$)        int64
# Spending Score (1-100)    int64
# dtype: object

# %%
sns.pairplot(pd.DataFrame(scaled_data, columns=data.columns))
plt.show()

# %%
plt.plot(range(1, 11), sse)
plt.xlabel('Number of Clusters (K)')
plt.ylabel('SSE')
plt.title('Elbow Method for Optimal K')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Example DataFrame creation (remove this part if you already have your DataFrame)
# data = pd.DataFrame({
#     'Annual Income (k$)': [15, 16, 17],
#     'Spending Score (1-100)': [39, 81, 6],
#     'Cluster': [0, 1, 0]  # Ensure this column exists
# })

# Check if 'Cluster' exists and handle accordingly
if 'Cluster' not in data.columns:
    print("The 'Cluster' column does not exist. Please check your DataFrame.")
else:
    plt.figure(figsize=(10, 6))
    sns.scatterplot(x=data['Annual Income (k$)'], 
                    y=data['Spending Score (1-100)'], 
                    hue=data['Cluster'], 
                    palette='Set2', 
                    s=100)
    plt.title('Customer Segments based on Income and Spending Score')
    plt.show()
# Out:
# The 'Cluster' column does not exist. Please check your DataFrame.

# %%
sns.pairplot(data)
plt.show()

# %%
from sklearn.cluster import KMeans

# Define the number of clusters
n_clusters = 3

# Perform K-means clustering
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
data['Cluster'] = kmeans.fit_predict(data[['Annual Income (k$)', 'Spending Score (1-100)']])

# Plot the results with the Cluster column
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data['Annual Income (k$)'], 
                y=data['Spending Score (1-100)'], 
                hue=data['Cluster'], 
                palette='Set2', 
                s=100)
plt.title('Customer Segments based on Income and Spending Score')
plt.show()
# Out:
# E:\Users\DELL E7450\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
print(data.groupby('Cluster').mean())
# Out:
#            Gender        Age  Annual Income (k$)  Spending Score (1-100)
# Cluster
# 0        0.473684  40.394737           87.000000               18.631579
# 1        0.538462  32.692308           86.538462               82.128205
# 2        0.593496  40.325203           44.154472               49.829268
